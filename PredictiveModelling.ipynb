# %%
import pandas as pd
import os
import geopandas as gpd
import matplotlib.pyplot as plt

home_dir = "/scratch/hydro4/shared_data/uk_catchment_data/camels_gb_v2/"
# os.listdir(home_dir)

# %% [markdown]
# # Relationship between flow and precipitation
# Get dataframe with gauge locations and topographic variables

# %%
topography = pd.read_csv(home_dir + "Catchment_Attributes/CAMELS_GB_v2_topographic_attributes.csv")
topography = topography.drop(columns=['gauge_easting', 'gauge_northing'])
hydrologic_attributes = pd.read_csv(home_dir + "Catchment_Attributes/CAMELS_GB_v2_hydrologic_attributes.csv")
climatic_attributes = pd.read_csv(home_dir + "Catchment_Attributes/CAMELS_GB_v2_climatic_attributes.csv")

# %%
#

# %%
topography_with_precip = pd.merge(topography, climatic_attributes[['gauge_id', 'p_mean']])
topography_with_precip.columns
# Out:
# Index(['gauge_id', 'gauge_name', 'gauge_lat', 'gauge_lon', 'gauge_elev',
#        'area', 'dpsbar', 'elev_mean', 'elev_min', 'elev_10', 'elev_50',
#        'elev_90', 'elev_max', 'p_mean'],
#       dtype='object')

# %%
## Follows roughly what we'd expect, but with some outliers We could then look into the outliers?

# %%
fig, axs = plt.subplots(ncols=6, nrows=2, figsize=(10,4)) #wide, tall
axs=axs.flatten()
for ax_num, col in enumerate(topography_with_precip.columns[2:]):
    axs[ax_num].scatter(topography_with_precip[col], topography['p_mean'], s=2) 
    axs[ax_num].set_title(col)
fig.tight_layout()
for ax in axs[len(topography_with_precip.columns[2:]):]:
    ax.axis('off')

# %% [markdown]
# ## Building a model to predict the influence of catchment characteristics on runoff

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import multiprocessing
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import numpy as np

# %% [markdown]
# Deciding on the input variables

# %%
# The predictor variables
Xfull = topography.drop(['gauge_id', 'gauge_name', 'gauge_easting', 'gauge_northing'], axis =1)
Xfull = pd.DataFrame({'precip': climatic_attributes['p_mean']})
Xfull = climatic_attributes['p_mean']
# The variable to be predicted
Yfull = hydrologic_attributes['q_mean'].values

# %% [markdown]
# Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split( Xfull, Yfull,test_size=0.2, random_state=42)

# %% [markdown]
# Fit a linear model

# %%
lin_model = Pipeline([("scaler", StandardScaler()),("model", LinearRegression())])
lin_model.fit(X_train, y_train)
y_pred_lin = lin_model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 2
#       1 lin_model = Pipeline([("scaler", StandardScaler()),("model", LinearRegression())])
# ----> 2 lin_model.fit(X_train, y_train)
#       3 y_pred_lin = lin_model.predict(X_test)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/sklearn/pipeline.py:655, in Pipeline.fit(self, X, y, **params)
#     648     raise ValueError(
#     649         "The `transform_input` parameter can only be set if metadata "
#     650         "routing is enabled. You can enable metadata routing using "
#     651         "`sklearn.set_config(enable_metadata_routing=True)`."
#     652     )
#     654 routed_params = self._check_method_params(method="fit", props=params)
# --> 655 Xt = self._fit(X, y, routed_params, raw_params=params)
#     656 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     657     if self._final_estimator != "passthrough":
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/sklearn/pipeline.py:589, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     582 # Fit or load from cache the current transformer
#     583 step_params = self._get_metadata_for_step(
#     584     step_idx=step_idx,
#     585     step_params=routed_params[name],
#     586     all_params=raw_params,
#     587 )
# --> 589 X, fitted_transformer = fit_transform_one_cached(
#     590     cloned_transformer,
#     591     X,
#     592     y,
#     593     weight=None,
#     594     message_clsname="Pipeline",
#     595     message=self._log_message(step_idx),
#     596     params=step_params,
#     597 )
#     598 # Replace the transformer of the step with the fitted
#     599 # transformer. This is necessary when loading the transformer
#     600 # from the cache.
#     601 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/joblib/memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/sklearn/pipeline.py:1540, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1538 with _print_elapsed_time(message_clsname, message):
#    1539     if hasattr(transformer, "fit_transform"):
# -> 1540         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1541     else:
#    1542         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1543             X, **params.get("transform", {})
#    1544         )
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/sklearn/base.py:897, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     894     return self.fit(X, **fit_params).transform(X)
#     895 else:
#     896     # fit method of arity 2 (supervised transformation)
# --> 897     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:907, in StandardScaler.fit(self, X, y, sample_weight)
#     905 # Reset internal state before fitting
#     906 self._reset()
# --> 907 return self.partial_fit(X, y, sample_weight)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:943, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     911 """Online computation of mean and std on X for later scaling.
#     912
#     913 All of X is processed as a single batch. This is intended for cases
#    (...)
#     940     Fitted scaler.
#     941 """
#     942 first_call = not hasattr(self, "n_samples_seen_")
# --> 943 X = validate_data(
#     944     self,
#     945     X,
#     946     accept_sparse=("csr", "csc"),
#     947     dtype=FLOAT_DTYPES,
#     948     ensure_all_finite="allow-nan",
#     949     reset=first_call,
#     950 )
#     951 n_features = X.shape[1]
#     953 if sample_weight is not None:
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/sklearn/utils/validation.py:2954, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2952         out = X, y
#    2953 elif not no_val_X and no_val_y:
# -> 2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
#    2956     out = _check_y(y, **check_params)
#
# File ~/anaconda3/envs/futureflood/lib/python3.10/site-packages/sklearn/utils/validation.py:1091, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1084         else:
#    1085             msg = (
#    1086                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1087                 "Reshape your data either using array.reshape(-1, 1) if "
#    1088                 "your data has a single feature or array.reshape(1, -1) "
#    1089                 "if it contains a single sample."
#    1090             )
# -> 1091         raise ValueError(msg)
#    1093 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1094     raise ValueError(
#    1095         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1096         "Convert your data to numeric values explicitly instead."
#    1097     )
#
# ValueError: Expected a 2-dimensional container but got <class 'pandas.core.series.Series'> instead. Pass a DataFrame containing a single row (i.e. single sample) or a single column (i.e. single feature) instead.

# %% [markdown]
# Fit a random forest model

# %%
rf_model = RandomForestRegressor(n_estimators=300, max_depth=None, random_state=42,n_jobs=-1)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

# %% [markdown]
# Fit XGB model

# %%
xgb_model = XGBRegressor( n_estimators=300,learning_rate=0.05,max_depth=4,subsample=0.8, colsample_bytree=0.8, random_state=42)
xgb_model.fit(X_train, y_train)
y_pred_xgb = xgb_model.predict(X_test)

# %% [markdown]
# Evaluate model performance

# %%
def evaluate(y_true, y_pred):
    return {"R2": r2_score(y_true, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_true, y_pred)),
        "MAE": mean_absolute_error(y_true, y_pred)}

results = pd.DataFrame({"Linear Regression": evaluate(y_test, y_pred_lin),"Random Forest": evaluate(y_test, y_pred_rf),
    "XGBoost": evaluate(y_test, y_pred_xgb)})

print(results)
# Out:
#       Linear Regression  Random Forest   XGBoost
# R2             0.717085       0.871520  0.863183
# RMSE           0.870696       0.586755  0.605492
# MAE            0.596100       0.391004  0.386352

# %%
def evaluate(y_true, y_pred):
    return {"R2": r2_score(y_true, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_true, y_pred)),
        "MAE": mean_absolute_error(y_true, y_pred)}

results = pd.DataFrame({"Linear Regression": evaluate(y_test, y_pred_lin),"Random Forest": evaluate(y_test, y_pred_rf),
    "XGBoost": evaluate(y_test, y_pred_xgb)})

print(results)
# Out:
#       Linear Regression  Random Forest   XGBoost
# R2             0.886179       0.891547  0.910141
# RMSE           0.552269       0.539087  0.490705
# MAE            0.256195       0.270373  0.269901

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)
lin = LinearRegression()

r2_lin = cross_val_score(lin, Xfull, Yfull, cv=kf, scoring='r2')
rmse_lin = -cross_val_score(lin, Xfull, Yfull, cv=kf,
                            scoring='neg_root_mean_squared_error')

print("Linear Regression")
print("Mean R2:", r2_lin.mean())
print("Mean RMSE:", rmse_lin.mean())
# Out:
# Linear Regression
# Mean R2: 0.9166472948366785
# Mean RMSE: 0.4390420573545339

# %%
rf = RandomForestRegressor(random_state=42)

r2_rf = cross_val_score(rf, Xfull, Yfull, cv=kf, scoring='r2')
rmse_rf = -cross_val_score(rf, Xfull, Yfull, cv=kf,
                           scoring='neg_root_mean_squared_error')

print("Random Forest")
print("Mean R2:", r2_rf.mean())
print("Mean RMSE:", rmse_rf.mean())
# Out:
# Random Forest
# Mean R2: 0.9236819761856422
# Mean RMSE: 0.4305455055052585

# %%
xgb = XGBRegressor(random_state=42)

r2_xgb = cross_val_score(xgb, Xfull, Yfull, cv=kf, scoring='r2')
rmse_xgb = -cross_val_score(xgb, Xfull, Yfull, cv=kf,
                            scoring='neg_root_mean_squared_error')

print("XGBoost")
print("Mean R2:", r2_xgb.mean())
print("Mean RMSE:", rmse_xgb.mean())
# Out:
# XGBoost
# Mean R2: 0.8988254122665392
# Mean RMSE: 0.4948708345762788

# %% [markdown]
#  Feature importance (Random Forest)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=500,random_state=42, n_jobs=-1)
rf.fit(Xfull, Yfull)
importances = pd.Series(rf.feature_importances_,index=Xfull.columns).sort_values(ascending=False)


plt.figure(figsize=(8, 6))
importances.sort_values().plot(kind="barh")
plt.xlabel("Feature Importance")
plt.title("Random Forest Feature Importances")
plt.tight_layout()

# %%
import seaborn as sns

sns.histplot(Yfull, kde=True)
plt.title("Distribution of Mean Q")
plt.show()

from scipy.stats import skew

print("Skewness:", skew(Yfull))

import numpy as np

sns.histplot(np.log1p(Yfull), kde=True)
plt.title("Distribution of log(Mean Q)")
plt.show()

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(Xfull, Yfull, random_state=42)

model = LinearRegression().fit(X_train, y_train)
y_pred = model.predict(X_test)

residuals = y_test - y_pred
# Out:
# Skewness: 1.589289746830567

# %%
rf_raw = RandomForestRegressor(random_state=42)
rf_raw.fit(X_train, y_train)
r2_raw = rf_raw.score(X_test, y_test)
y_pred_raw = rf_raw.predict(X_test)

y_train_log = np.log1p(y_train)
y_test_log = np.log1p(y_test)

rf_log = RandomForestRegressor(random_state=42)
rf_log.fit(X_train, y_train_log)

y_pred_log = rf_log.predict(X_test)
y_pred_back = np.expm1(y_pred_log)

r2_log = r2_score(y_test, y_pred_back)

print(r2_raw, r2_log)

rmse_raw = np.sqrt(mean_squared_error(y_test, y_pred_raw))
rmse_log = np.sqrt(mean_squared_error(y_test, y_pred_back))
print(r2_raw, r2_log)
# Out:
# 0.8393826750829971 0.8217707875761211
# 0.8393826750829971 0.8217707875761211

# %%
plt.scatter(y_pred_raw, y_test - y_pred_raw)
plt.title("Raw model residuals")
plt.show()

plt.scatter(y_pred_back, y_test - y_pred_back)
plt.title("Log model residuals (back-transformed)")
plt.show()

# %%
# Split data into training and test sets
X_train, X_temp, Y_train, Y_temp = \
    train_test_split(Xfull, Yfull, test_size=0.6666, random_state=123)
# Split off another training set now to train the hyperparameters using the two best models from above
X_validate, X_finaltest, Y_validate, Y_finaltest = \
    train_test_split(X_temp, Y_temp, test_size=0.5, random_state=123)

# %%
# climatic_attributes = pd.read_csv(home_dir + "Catchment_Timeseries/Hydro-Meteorological/Daily/CAMELS_GB_v2_hydromet_daily_timeseries_10002_19701001-20220930.csv")
# climatic_attributes.head()

# %%
# cachment_boundaries = gpd.read_file(home_dir + "Catchment_Boundaries/CAMELS_GB_v2_catchment_boundaries.shp")
# # cachment_boundaries.plot()

# %%
# nrfa = gpd.read_file("/scratch/hydro4/shared_data/uk_catchment_data/shapefile_boundaries/NRFACatchmentsAll-2024.shp")
# nrfa.plot(color = 'None', linewidth= 1)
# nrfa.crs
