# %% [markdown]
# Now that we're beginning to understand the locations at which the CAMELS dataset records measurements and some of the variables which it measures, it would be good to start looking at whether we can find connections between those variables.

# %%
# topography = pd.read_csv(home_dir + "Catchment_Attributes/CAMELS_GB_v2_topographic_attributes.csv")
hydrogeology = pd.read_csv(home_dir + "Catchment_Attributes/CAMELS_GB_v2_hydrogeology_attributes.csv")
soils = pd.read_csv(home_dir + "Catchment_Attributes/CAMELS_GB_v2_soil_attributes.csv")

# %%
home_dir = "/scratch/hydro4/shared_data/uk_catchment_data/camels_gb_v2/"
import os
# os.listdir("/scratch/hydro4/shared_data/uk_catchment_data/camels_gb_v2/Catchment_Boundaries")

# %% [markdown]
# First of all we need to load in the data. Load topography like before, but also additionally hydrologic attributes and climatic attributes.

# %%
import pandas as pd
topography = pd.read_csv(home_dir + "Catchment_Attributes/CAMELS_GB_v2_topographic_attributes.csv")
hydrologic_attributes = pd.read_csv(home_dir + "Catchment_Attributes/CAMELS_GB_v2_hydrologic_attributes.csv")
climatic_attributes = pd.read_csv(home_dir + "Catchment_Attributes/CAMELS_GB_v2_climatic_attributes.csv")
# gauge_locs = topography[['gauge_id', 'gauge_lat', 'gauge_lon']]
del topography['gauge_easting']
del topography['gauge_northing']

# %% [markdown]
# ### Relationship between hydrologic signatures and catchment properties

# %% [markdown]
# The hydrologic signatures characterise long-term (i.e. mean flow, runoff ratio, streamflow elasticity, baseflow index), seasonal (i.e. the half 300 low date), and short-term (i.e. high and low flow percentiles, frequency and duration of high and low streamflow events) streamflow dynamics.

# %% [markdown]
# This time we are going to join (maybe this isnt actually necessary?)

# %%
merged = (topography
        .merge(climatic_attributes, on="gauge_id", how="left")
        .merge(hydrologic_attributes, on="gauge_id", how="left")
         .merge(hydrogeology, on="gauge_id", how="left"))

# %% [markdown]
# Plot one relationship, and then ask them to look through the datasets and think if there's some other variables they'd
# like to see the relationship between. Then show them how to plot them all

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))

sc = plt.scatter(
    merged['p_mean'],
    merged['q_mean'],
#     c=hydrogeology['no_gw_perc'],
    c=merged['baseflow_index'],
    cmap='viridis', s=25, edgecolor = 'black', linewidth=0.3)

plt.xlabel('Mean Precipitation (mm / day)')
plt.ylabel('Mean Runoff (mm / day)')

plt.colorbar(sc, label='Baseflow index (%)')

max_val = max(climatic_attributes['p_mean'].max(), hydrologic_attributes['q_mean'].max())
plt.plot([0, max_val], [0, max_val], 'k--', linewidth=1);

# %%
from shapely import Point
# Get just the gauge location information
# Construct the geometry from the latitude and longitude using Shapely
geometry = [Point(xy) for xy in zip(merged.gauge_lon, merged.gauge_lat)]
# Create the geodataframe
# gauge_locs = topography.drop(['gauge_lon', 'gauge_lat'], axis=1)
merged_gdf = gpd.GeoDataFrame(merged, crs="EPSG:4326", geometry=geometry)

# %%
plt.scatter(merged['p_mean'], merged['runoff_ratio'])

# %%
some.loc[some['runoff_ratio'] > 1.5,['runoff_ratio', 'no_gw_perc']]
# Out:
#      runoff_ratio  no_gw_perc
# 108          3.01       51.55
# 126          2.74       27.43

# %%
merged_gdf_3857 = merged_gdf.to_crs(epsg=3857)
some = merged_gdf_3857.sort_values('runoff_ratio', ascending=False)[:8]

import contextily as ctx

fig,ax=plt.subplots(figsize=(8,8))
some.plot('runoff_ratio', ax=ax, markersize=15, legend=True, # cmap='Purples',
            legend_kwds={"label": "Days / yr", "orientation": "vertical"})

ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# %%
# merged['runoff_ratio'] = merged['q_mean'] / merged['p_mean']
merged.sort_values('runoff_ratio', ascending=False)[['gauge_id', 'gauge_name','runoff_ratio']][:8]
# Out:
#      gauge_id                          gauge_name  runoff_ratio
# 108     26006   Elmswell Beck at Little Driffield          3.01
# 126     27038            Costa Beck at Gatehouses          2.74
# 387     44009                     Wey at Broadwey          1.39
# 137     27073      Brompton Beck at Snainton Ings          1.30
# 33      15016                      Tay at Kenmore          1.06
# 530     65008                 Peris at Nant Peris          1.06
# 656     89005                 Lochy at Inverlochy          1.01
# 302     39061  Letcombe Brook at Letcombe Bassett          1.00

# %%
fig, axs = plt.subplots(ncols=6, nrows=7, figsize=(10,14)) #wide, tall
axs=axs.flatten()
for ax_num, col in enumerate(merged.columns[3:]):
    if not merged[col].dtype == object:
        axs[ax_num].scatter(merged['p_mean'], merged['q_mean'], c=merged[col],
            cmap='viridis', s=25, edgecolor = 'black', linewidth=0.3)
        axs[ax_num].set_title(col)
fig.tight_layout()
# for ax in axs[len(merged.columns[2:]):]:
#     ax.axis('off')

# %%
## Follows roughly what we'd expect, but with some outliers We could then look into the outliers?

# %%
fig, axs = plt.subplots(ncols=6, nrows=2, figsize=(10,4)) #wide, tall
axs=axs.flatten()
for ax_num, col in enumerate(topography_with_precip.columns[2:]):
    axs[ax_num].scatter(topography_with_precip[col], topography_with_precip['p_mean'], s=2) 
    axs[ax_num].set_title(col)
fig.tight_layout()
for ax in axs[len(topography_with_precip.columns[2:]):]:
    ax.axis('off')
